# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

cities = []

#get the nearest city for each coordinate from citipy
for coordinate in coordinates:
        # each row in coordinates list, grab lat from column 0 and long from column 1. Get the name of the nearest city.
        city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
       
        # if city is new, add it to the list
        if city not in cities:
                cities.append(city)
                              
#That gave us a list of cities, one for each of our random coordinates.
#How many cities did we get?
len(cities)
# Out:
# 762

# %%
cities
# Out:
# ['mataura',
#  'searcy',
#  'cap malheureux',
#  'pevek',
#  'wajid',
#  'lebu',
#  'ostrovnoy',
#  'taoudenni',
#  'ushuaia',
#  'rzhev',
#  'georgetown',
#  'shahjahanpur',
#  'mar del plata',
#  'sao sebastiao',
#  'tiksi',
#  'amderma',
#  'puerto ayora',
#  'bredasdorp',
#  'dikson',
#  'peniche',
#  'mahanoro',
#  'poum',
#  'swellendam',
#  'arraial do cabo',
#  'carnarvon',
#  'paamiut',
#  'lompoc',
#  'tema',
#  'torbay',
#  'tavda',
#  'new norfolk',
#  'guerrero negro',
#  'punta arenas',
#  'troitsko-pechorsk',
#  'port alfred',
#  'alice springs',
#  'avarua',
#  'busselton',
#  'te anau',
#  'saskylakh',
#  'butaritari',
#  'iqaluit',
#  'saint-philippe',
#  'nyurba',
#  'cape town',
#  'longyearbyen',
#  'yumen',
#  'rungata',
#  'najran',
#  'bluff',
#  'palmer',
#  'hithadhoo',
#  'jamestown',
#  'kapaa',
#  'ribeira grande',
#  'provideniya',
#  'rikitea',
#  'turukhansk',
#  'east london',
#  'sarishabari',
#  'vaitupu',
#  'salalah',
#  'san patricio',
#  'kruisfontein',
#  'bagar',
#  'margate',
#  'albany',
#  'dale',
#  'iberia',
#  'sioux lookout',
#  'sitka',
#  'zenzeli',
#  'faanui',
#  'price',
#  'xiaoweizhai',
#  'nacala',
#  'canutama',
#  'isangel',
#  'thinadhoo',
#  'belushya guba',
#  'gat',
#  'upernavik',
#  'sturgis',
#  'mackenzie',
#  'geraldton',
#  'lemesos',
#  'port lincoln',
#  'yamada',
#  'dickinson',
#  'solnechnyy',
#  'port hardy',
#  'kongwa',
#  'hobart',
#  'leningradskiy',
#  'sao filipe',
#  'hami',
#  'pacific grove',
#  'severo-kurilsk',
#  'tuatapere',
#  'padang',
#  'hermanus',
#  'hasaki',
#  'luanda',
#  'khatanga',
#  'tezu',
#  'mehamn',
#  'poltava',
#  'vysokogornyy',
#  'vardo',
#  'xai-xai',
#  'mount gambier',
#  'tabiauea',
#  'bonavista',
#  'dingle',
#  'sentyabrskiy',
#  'tasiilaq',
#  'porbandar',
#  'airai',
#  'angoche',
#  'makakilo city',
#  'bonthe',
#  'saint-gaudens',
#  'taolanaro',
#  'thoen',
#  'norman wells',
#  'atuona',
#  'hilo',
#  'barrow',
#  'laguna',
#  'beringovskiy',
#  'constitucion',
#  'chuy',
#  'tingrela',
#  'lodja',
#  'ulaangom',
#  'deputatskiy',
#  'illoqqortoormiut',
#  'katsuura',
#  'wuhu',
#  'flin flon',
#  'moron',
#  'mackay',
#  'udachnyy',
#  'ixtapa',
#  'fortuna',
#  'karkaralinsk',
#  'celestun',
#  'hamilton',
#  'winter springs',
#  'ahipara',
#  'tura',
#  'taltal',
#  'tautira',
#  'broken hill',
#  'port elizabeth',
#  'ancud',
#  'yellowknife',
#  'cobourg',
#  'morgan city',
#  'anjar',
#  'muzhi',
#  'barentsburg',
#  'saint-joseph',
#  'anadyr',
#  'mikuni',
#  'kulhudhuffushi',
#  'vestmanna',
#  'yeniseysk',
#  'cabo san lucas',
#  'perth amboy',
#  'nikolskoye',
#  'ambulu',
#  'avera',
#  'ponta do sol',
#  'anderson',
#  'vaini',
#  'bengkulu',
#  'araouane',
#  'biak',
#  'chokurdakh',
#  'redmond',
#  'kamenskoye',
#  'esperance',
#  'soyo',
#  'aykhal',
#  'ihosy',
#  'kavieng',
#  'bosaso',
#  'suleja',
#  'sarangani',
#  'sabang',
#  'namibe',
#  'san esteban',
#  'hobyo',
#  'lavrentiya',
#  'bambous virieux',
#  'ammon',
#  'kahului',
#  'hay river',
#  'kurkino',
#  'lethem',
#  'zaysan',
#  'misratah',
#  'denpasar',
#  'yantal',
#  'maragogi',
#  'mahajanga',
#  'pizhanka',
#  'castro',
#  'bandarbeyla',
#  'aripuana',
#  'ileza',
#  'namatanai',
#  'carutapera',
#  'tazovskiy',
#  'northam',
#  'hofn',
#  'prince rupert',
#  'vutcani',
#  'oistins',
#  'nampula',
#  'boguchany',
#  'attawapiskat',
#  'noumea',
#  'mildura',
#  'fort nelson',
#  'alugan',
#  'discovery bay',
#  'cayenne',
#  'san cristobal',
#  'temaraia',
#  'saint-francois',
#  'bathsheba',
#  'kawalu',
#  'bolungarvik',
#  'port-gentil',
#  'qaanaaq',
#  'bubaque',
#  'qaqortoq',
#  'babanusah',
#  'acolla',
#  'omsukchan',
#  'mariental',
#  'rawlins',
#  'petatlan',
#  'olovyannaya',
#  'lucea',
#  'richards bay',
#  'necochea',
#  'knysna',
#  'burica',
#  'marzuq',
#  'portland',
#  'vredendal',
#  'curup',
#  'ngerengere',
#  'yangambi',
#  'sao joao da barra',
#  'ashqelon',
#  'palabuhanratu',
#  'sesheke',
#  'port shepstone',
#  'thompson',
#  'wanning',
#  'vao',
#  'goderich',
#  'shieli',
#  'kibala',
#  'quatre cocos',
#  'iquique',
#  'kuche',
#  'hun',
#  'opuwo',
#  'dolbeau',
#  'tuktoyaktuk',
#  'sola',
#  'phnum penh',
#  'victoria',
#  'sheboygan',
#  'port blair',
#  'banjar',
#  'gisborne',
#  'axim',
#  'joutseno',
#  'oriximina',
#  'tilichiki',
#  'mvangue',
#  'acapulco',
#  'narsaq',
#  'cidreira',
#  'anar darreh',
#  'mortka',
#  'verkhovazhye',
#  'port macquarie',
#  'asosa',
#  'clyde river',
#  'kodiak',
#  'umzimvubu',
#  'yulara',
#  'mahina',
#  'evensk',
#  'houston',
#  'sheregesh',
#  'kavaratti',
#  'ibra',
#  'tessalit',
#  'iracoubo',
#  'atar',
#  'rawson',
#  'dakar',
#  'shubarshi',
#  'kropotkin',
#  'pasni',
#  'samusu',
#  'roma',
#  'lorengau',
#  'bacolod',
#  'prince george',
#  'olafsvik',
#  'gimbi',
#  'klyuchi',
#  'yarmouth',
#  'khash',
#  'baiyin',
#  'karratha',
#  'naantali',
#  'santiago',
#  'dunedin',
#  'la ronge',
#  'meyungs',
#  'kangaatsiaq',
#  'brae',
#  'minden',
#  'san quintin',
#  'sibay',
#  'roros',
#  'sendafa',
#  'pingliang',
#  'martinsicuro',
#  'mahebourg',
#  'fernie',
#  'moen',
#  'andenes',
#  'hostotipaquillo',
#  'ilulissat',
#  'coquimbo',
#  'mullaitivu',
#  'naihati',
#  'great yarmouth',
#  'aksha',
#  'pontiac',
#  'korla',
#  'luwuk',
#  'huaidian',
#  'seoul',
#  'tornio',
#  'kaitangata',
#  'jiddah',
#  'litovko',
#  'skogn',
#  'xining',
#  'bam',
#  'los llanos de aridane',
#  'aklavik',
#  'souillac',
#  'antalaha',
#  'pavlovka',
#  'nizhneyansk',
#  'tevriz',
#  'nanortalik',
#  'husavik',
#  'fairbanks',
#  'khromtau',
#  'karasburg',
#  'luderitz',
#  'rudsar',
#  'san juan',
#  'sasovo',
#  'coahuayana',
#  'grand river south east',
#  'saint george',
#  'vanimo',
#  'north bend',
#  'lufilufi',
#  'komsomolskiy',
#  'guinabsan',
#  'lancaster',
#  'sestri levante',
#  'hailar',
#  'alikalia',
#  'kosa',
#  'polyarnyy',
#  'onega',
#  'belmonte',
#  'junin',
#  'magway',
#  'mount isa',
#  'zhangjiakou',
#  'emirdag',
#  'morondava',
#  'buala',
#  'pangai',
#  'kendal',
#  'camocim',
#  'charagua',
#  'alofi',
#  'taupo',
#  'college',
#  'saryozek',
#  'bulawayo',
#  'bilma',
#  'lohja',
#  'buraydah',
#  'ziyang',
#  'gigmoto',
#  'mayo',
#  'tasbuget',
#  'smithers',
#  'nome',
#  'lubao',
#  'saleaula',
#  'lerwick',
#  'zabol',
#  'camp verde',
#  'rocha',
#  'saldanha',
#  'luena',
#  'tsumeb',
#  'simoes',
#  'labuan',
#  'bakchar',
#  'le vauclin',
#  'mrirt',
#  'tsihombe',
#  'tulsa',
#  'labuhan',
#  'tigil',
#  'barabash',
#  'kusti',
#  'malwan',
#  'pahrump',
#  'lubu',
#  'kon tum',
#  'saint-pierre',
#  'tadepallegudem',
#  'hoshcha',
#  'tabialan',
#  'road town',
#  'nabire',
#  'ambilobe',
#  'taywarah',
#  'orcopampa',
#  'bafra',
#  'grootfontein',
#  'homer',
#  'strandby',
#  'ulladulla',
#  'tual',
#  'saint-leu',
#  'kassala',
#  'macaboboni',
#  'zhezkazgan',
#  'salur',
#  'pisco',
#  'jinchang',
#  'atasu',
#  'savalou',
#  'pemangkat',
#  'ojinaga',
#  'broome',
#  'kralendijk',
#  'bokspits',
#  'maloy',
#  'apahida',
#  'kaeo',
#  'boyolangu',
#  'troitskoye',
#  'touros',
#  'manggar',
#  'skjervoy',
#  'parabel',
#  'qandala',
#  'erenhot',
#  'roshchino',
#  'jalu',
#  'ustka',
#  'santa rosa',
#  'satitoa',
#  'maldonado',
#  'povenets',
#  'ramat yishay',
#  'baykit',
#  'beloha',
#  'half moon bay',
#  'georgiyevka',
#  'zwedru',
#  'zhigansk',
#  'vagay',
#  'srednekolymsk',
#  'halifax',
#  'mizan teferi',
#  'egvekinot',
#  'labutta',
#  'abha',
#  'bohl-iggelheim',
#  'owando',
#  'kedougou',
#  'victoria point',
#  'matara',
#  'seymchan',
#  'fernandopolis',
#  'caravelas',
#  'acarau',
#  'santa catarina de tepehuanes',
#  'buckeye',
#  'meadow lake',
#  'meulaboh',
#  'benalla',
#  'matagami',
#  'banda aceh',
#  'khani',
#  'llata',
#  'ballina',
#  'sovetskiy',
#  'yarada',
#  'naron',
#  'monze',
#  'la tuque',
#  'waipawa',
#  'yar-sale',
#  'eyl',
#  'hermosillo',
#  'pangnirtung',
#  'la rioja',
#  'nueva concepcion',
#  'mocambique',
#  'hare bay',
#  'haines junction',
#  'solin',
#  'ampanihy',
#  'klaksvik',
#  'ogulin',
#  'muisne',
#  'biltine',
#  'joshimath',
#  'zolotinka',
#  'krasni okny',
#  'ourinhos',
#  'honningsvag',
#  'de aar',
#  'ceska trebova',
#  'katobu',
#  'falealupo',
#  'orsha',
#  'puerto carreno',
#  'moanda',
#  'bilibino',
#  'zaozerne',
#  'camacha',
#  'aswan',
#  'somerville',
#  'raudeberg',
#  'mazamari',
#  'champerico',
#  'talnakh',
#  'ekibastuz',
#  'nautla',
#  'hammerfest',
#  'zavitinsk',
#  'claver',
#  'katangli',
#  'sao felix do xingu',
#  'flinders',
#  'greencastle',
#  'bitlis',
#  'sept-iles',
#  'fort saint james',
#  'wajima',
#  'puerto madryn',
#  'gramsh',
#  'malinyi',
#  'novikovo',
#  'port-cartier',
#  'merauke',
#  'merrill',
#  'kroderen',
#  'makung',
#  'sulangan',
#  'abu zabad',
#  'mandera',
#  'rawannawi',
#  'tahe',
#  'waingapu',
#  'talcahuano',
#  'tolbazy',
#  'leshukonskoye',
#  'whitehorse',
#  'masjed-e soleyman',
#  'magadi',
#  'tamale',
#  'mareeba',
#  'rupert',
#  'kumbo',
#  'alotau',
#  'moranbah',
#  'desaguadero',
#  'lagoa',
#  'sur',
#  'faya',
#  'semey',
#  'kamenka',
#  'bend',
#  'pucallpa',
#  'staryy nadym',
#  'asau',
#  'yabrud',
#  'jaru',
#  'rundu',
#  'hyderabad',
#  'afmadu',
#  'ginda',
#  'caconda',
#  'huazolotitlan',
#  'codrington',
#  'mergui',
#  'barra',
#  'kaniama',
#  'kudahuvadhoo',
#  'itoman',
#  'manavalakurichi',
#  'christchurch',
#  'bijela',
#  'altay',
#  'spirit river',
#  'dong hoi',
#  'bhag',
#  'vila franca do campo',
#  'ponnani',
#  'almaznyy',
#  'greytown',
#  'marsh harbour',
#  'muros',
#  'turbat',
#  'chulman',
#  'yeppoon',
#  'kondinskoye',
#  'iskateley',
#  'batagay-alyta',
#  'miri',
#  'silver city',
#  'colomi',
#  'trelew',
#  'santa cruz',
#  'hashtrud',
#  'nouadhibou',
#  'arona',
#  'henties bay',
#  'severobaykalsk',
#  'bara',
#  'bethel',
#  'hukuntsi',
#  'karamea',
#  'san lawrenz',
#  'ulverstone',
#  'zverinogolovskoye',
#  'lukovetskiy',
#  'tidore',
#  'marystown',
#  'yerofey pavlovich',
#  'mudgee',
#  'terney',
#  'calvia',
#  'rize',
#  'wana',
#  'bundaberg',
#  'sakakah',
#  'vila velha',
#  'san nicolas',
#  'consett',
#  'dolores',
#  'okha',
#  'launceston',
#  'brownwood',
#  'ciras',
#  'tomohon',
#  'tymovskoye',
#  'mutare',
#  'rizhao',
#  'kharp',
#  'bridgetown',
#  'maloshuyka',
#  'cantaura',
#  'warqla',
#  'chiang kham',
#  'lesnoye',
#  'ca mau',
#  'matam',
#  'yorkton',
#  'berlevag',
#  'tostamaa',
#  'isla vista',
#  'marawi',
#  'arman',
#  'newton',
#  'murray bridge',
#  'shimoda',
#  'roblin',
#  'areia branca',
#  'lahijan',
#  'nadym',
#  'caucasia',
#  'letpadan',
#  'martapura',
#  'emerald',
#  'glossa',
#  'batagay',
#  'agadez',
#  'anahuac',
#  'maun',
#  'cesenatico',
#  'sambava',
#  'havoysund',
#  'cap-aux-meules',
#  'phan thiet',
#  'mogadishu',
#  'shaunavon',
#  'vostok',
#  'samalaeulu',
#  'suining',
#  'nago',
#  'zhanakorgan',
#  'kloulklubed',
#  'rio grande',
#  'calera',
#  'lakes entrance',
#  'dolinsk',
#  'tutoia',
#  'kununurra',
#  'babaeski',
#  'mwinilunga',
#  'itarema',
#  'nogliki',
#  'johi',
#  'vermilion',
#  'lolua',
#  'kota belud',
#  'invermere',
#  'rorvik',
#  'umiray',
#  'barawe',
#  'van',
#  'ust-kut',
#  'bagdarin',
#  'vung tau',
#  'camara de lobos',
#  'ndjole',
#  'eydhafushi',
#  'tuy hoa',
#  'palembang',
#  'walvis bay',
#  'cajnice',
#  'subaytilah']

# %%
# Set up for API call with the OpenWeatherMap.

#pull in the Python Requests library to be able to request JSON data
import requests

#why do we need the datetime module from the datetime library?
#Oh... we don't need this if we don't pull city_date
#from datetime import datetime

#pull in my API key for the weather site
from config import weather_api_key

# Base URL for Weather Map API call with my key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print start of status of weather data pull
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#added city description. Kept country from the module code for ease of understanding. Removed date and date handling.

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("No weather data found. Skipping a city...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | searcy
# Processing Record 3 of Set 1 | cap malheureux
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | wajid
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | ostrovnoy
# Processing Record 8 of Set 1 | taoudenni
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | rzhev
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | shahjahanpur
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | sao sebastiao
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | amderma
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | peniche
# Processing Record 21 of Set 1 | mahanoro
# Processing Record 22 of Set 1 | poum
# Processing Record 23 of Set 1 | swellendam
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | paamiut
# Processing Record 27 of Set 1 | lompoc
# Processing Record 28 of Set 1 | tema
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | tavda
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | troitsko-pechorsk
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | te anau
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | nyurba
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | yumen
# Processing Record 48 of Set 1 | rungata
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 49 of Set 1 | najran
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | palmer
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | turukhansk
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | sarishabari
# Processing Record 11 of Set 2 | vaitupu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 12 of Set 2 | salalah
# Processing Record 13 of Set 2 | san patricio
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | bagar
# Processing Record 16 of Set 2 | margate
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | dale
# Processing Record 19 of Set 2 | iberia
# Processing Record 20 of Set 2 | sioux lookout
# Processing Record 21 of Set 2 | sitka
# Processing Record 22 of Set 2 | zenzeli
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | price
# Processing Record 25 of Set 2 | xiaoweizhai
# Processing Record 26 of Set 2 | nacala
# Processing Record 27 of Set 2 | canutama
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | thinadhoo
# Processing Record 30 of Set 2 | belushya guba
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 31 of Set 2 | gat
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | sturgis
# Processing Record 34 of Set 2 | mackenzie
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | lemesos
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | yamada
# Processing Record 39 of Set 2 | dickinson
# Processing Record 40 of Set 2 | solnechnyy
# Processing Record 41 of Set 2 | port hardy
# Processing Record 42 of Set 2 | kongwa
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | leningradskiy
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | pacific grove
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | padang
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | luanda
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | tezu
# Processing Record 6 of Set 3 | mehamn
# Processing Record 7 of Set 3 | poltava
# Processing Record 8 of Set 3 | vysokogornyy
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | xai-xai
# Processing Record 11 of Set 3 | mount gambier
# Processing Record 12 of Set 3 | tabiauea
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 13 of Set 3 | bonavista
# Processing Record 14 of Set 3 | dingle
# Processing Record 15 of Set 3 | sentyabrskiy
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | porbandar
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | angoche
# Processing Record 20 of Set 3 | makakilo city
# Processing Record 21 of Set 3 | bonthe
# Processing Record 22 of Set 3 | saint-gaudens
# Processing Record 23 of Set 3 | taolanaro
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 24 of Set 3 | thoen
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | laguna
# Processing Record 30 of Set 3 | beringovskiy
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | tingrela
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 34 of Set 3 | lodja
# Processing Record 35 of Set 3 | ulaangom
# Processing Record 36 of Set 3 | deputatskiy
# Processing Record 37 of Set 3 | illoqqortoormiut
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | wuhu
# Processing Record 40 of Set 3 | flin flon
# Processing Record 41 of Set 3 | moron
# Processing Record 42 of Set 3 | mackay
# Processing Record 43 of Set 3 | udachnyy
# Processing Record 44 of Set 3 | ixtapa
# Processing Record 45 of Set 3 | fortuna
# Processing Record 46 of Set 3 | karkaralinsk
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 47 of Set 3 | celestun
# Processing Record 48 of Set 3 | hamilton
# Processing Record 49 of Set 3 | winter springs
# Processing Record 50 of Set 3 | ahipara
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | taltal
# Processing Record 3 of Set 4 | tautira
# Processing Record 4 of Set 4 | broken hill
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | cobourg
# Processing Record 9 of Set 4 | morgan city
# Processing Record 10 of Set 4 | anjar
# Processing Record 11 of Set 4 | muzhi
# Processing Record 12 of Set 4 | barentsburg
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 13 of Set 4 | saint-joseph
# Processing Record 14 of Set 4 | anadyr
# Processing Record 15 of Set 4 | mikuni
# Processing Record 16 of Set 4 | kulhudhuffushi
# Processing Record 17 of Set 4 | vestmanna
# Processing Record 18 of Set 4 | yeniseysk
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | perth amboy
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | ambulu
# Processing Record 23 of Set 4 | avera
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | anderson
# Processing Record 26 of Set 4 | vaini
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | araouane
# Processing Record 29 of Set 4 | biak
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | redmond
# Processing Record 32 of Set 4 | kamenskoye
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | soyo
# Processing Record 35 of Set 4 | aykhal
# Processing Record 36 of Set 4 | ihosy
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | bosaso
# Processing Record 39 of Set 4 | suleja
# Processing Record 40 of Set 4 | sarangani
# Processing Record 41 of Set 4 | sabang
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | san esteban
# Processing Record 44 of Set 4 | hobyo
# Processing Record 45 of Set 4 | lavrentiya
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | ammon
# Processing Record 48 of Set 4 | kahului
# Processing Record 49 of Set 4 | hay river
# Processing Record 50 of Set 4 | kurkino
# Processing Record 1 of Set 5 | lethem
# Processing Record 2 of Set 5 | zaysan
# Processing Record 3 of Set 5 | misratah
# Processing Record 4 of Set 5 | denpasar
# Processing Record 5 of Set 5 | yantal
# Processing Record 6 of Set 5 | maragogi
# Processing Record 7 of Set 5 | mahajanga
# Processing Record 8 of Set 5 | pizhanka
# Processing Record 9 of Set 5 | castro
# Processing Record 10 of Set 5 | bandarbeyla
# Processing Record 11 of Set 5 | aripuana
# Processing Record 12 of Set 5 | ileza
# Processing Record 13 of Set 5 | namatanai
# Processing Record 14 of Set 5 | carutapera
# Processing Record 15 of Set 5 | tazovskiy
# Processing Record 16 of Set 5 | northam
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | vutcani
# Processing Record 20 of Set 5 | oistins
# Processing Record 21 of Set 5 | nampula
# Processing Record 22 of Set 5 | boguchany
# Processing Record 23 of Set 5 | attawapiskat
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 24 of Set 5 | noumea
# Processing Record 25 of Set 5 | mildura
# Processing Record 26 of Set 5 | fort nelson
# Processing Record 27 of Set 5 | alugan
# Processing Record 28 of Set 5 | discovery bay
# Processing Record 29 of Set 5 | cayenne
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | temaraia
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 32 of Set 5 | saint-francois
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | kawalu
# Processing Record 35 of Set 5 | bolungarvik
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 36 of Set 5 | port-gentil
# Processing Record 37 of Set 5 | qaanaaq
# Processing Record 38 of Set 5 | bubaque
# Processing Record 39 of Set 5 | qaqortoq
# Processing Record 40 of Set 5 | babanusah
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 41 of Set 5 | acolla
# Processing Record 42 of Set 5 | omsukchan
# Processing Record 43 of Set 5 | mariental
# Processing Record 44 of Set 5 | rawlins
# Processing Record 45 of Set 5 | petatlan
# Processing Record 46 of Set 5 | olovyannaya
# Processing Record 47 of Set 5 | lucea
# Processing Record 48 of Set 5 | richards bay
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | knysna
# Processing Record 1 of Set 6 | burica
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 2 of Set 6 | marzuq
# Processing Record 3 of Set 6 | portland
# Processing Record 4 of Set 6 | vredendal
# Processing Record 5 of Set 6 | curup
# Processing Record 6 of Set 6 | ngerengere
# Processing Record 7 of Set 6 | yangambi
# Processing Record 8 of Set 6 | sao joao da barra
# Processing Record 9 of Set 6 | ashqelon
# Processing Record 10 of Set 6 | palabuhanratu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 11 of Set 6 | sesheke
# Processing Record 12 of Set 6 | port shepstone
# Processing Record 13 of Set 6 | thompson
# Processing Record 14 of Set 6 | wanning
# Processing Record 15 of Set 6 | vao
# Processing Record 16 of Set 6 | goderich
# Processing Record 17 of Set 6 | shieli
# Processing Record 18 of Set 6 | kibala
# Processing Record 19 of Set 6 | quatre cocos
# Processing Record 20 of Set 6 | iquique
# Processing Record 21 of Set 6 | kuche
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 22 of Set 6 | hun
# Processing Record 23 of Set 6 | opuwo
# Processing Record 24 of Set 6 | dolbeau
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 25 of Set 6 | tuktoyaktuk
# Processing Record 26 of Set 6 | sola
# Processing Record 27 of Set 6 | phnum penh
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 28 of Set 6 | victoria
# Processing Record 29 of Set 6 | sheboygan
# Processing Record 30 of Set 6 | port blair
# Processing Record 31 of Set 6 | banjar
# Processing Record 32 of Set 6 | gisborne
# Processing Record 33 of Set 6 | axim
# Processing Record 34 of Set 6 | joutseno
# Processing Record 35 of Set 6 | oriximina
# Processing Record 36 of Set 6 | tilichiki
# Processing Record 37 of Set 6 | mvangue
# Processing Record 38 of Set 6 | acapulco
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | anar darreh
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 42 of Set 6 | mortka
# Processing Record 43 of Set 6 | verkhovazhye
# Processing Record 44 of Set 6 | port macquarie
# Processing Record 45 of Set 6 | asosa
# Processing Record 46 of Set 6 | clyde river
# Processing Record 47 of Set 6 | kodiak
# Processing Record 48 of Set 6 | umzimvubu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 49 of Set 6 | yulara
# Processing Record 50 of Set 6 | mahina
# Processing Record 1 of Set 7 | evensk
# Processing Record 2 of Set 7 | houston
# Processing Record 3 of Set 7 | sheregesh
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | ibra
# Processing Record 6 of Set 7 | tessalit
# Processing Record 7 of Set 7 | iracoubo
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | rawson
# Processing Record 10 of Set 7 | dakar
# Processing Record 11 of Set 7 | shubarshi
# Processing Record 12 of Set 7 | kropotkin
# Processing Record 13 of Set 7 | pasni
# Processing Record 14 of Set 7 | samusu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 15 of Set 7 | roma
# Processing Record 16 of Set 7 | lorengau
# Processing Record 17 of Set 7 | bacolod
# Processing Record 18 of Set 7 | prince george
# Processing Record 19 of Set 7 | olafsvik
# Processing Record 20 of Set 7 | gimbi
# Processing Record 21 of Set 7 | klyuchi
# Processing Record 22 of Set 7 | yarmouth
# Processing Record 23 of Set 7 | khash
# Processing Record 24 of Set 7 | baiyin
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | naantali
# Processing Record 27 of Set 7 | santiago
# Processing Record 28 of Set 7 | dunedin
# Processing Record 29 of Set 7 | la ronge
# Processing Record 30 of Set 7 | meyungs
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 31 of Set 7 | kangaatsiaq
# Processing Record 32 of Set 7 | brae
# Processing Record 33 of Set 7 | minden
# Processing Record 34 of Set 7 | san quintin
# Processing Record 35 of Set 7 | sibay
# Processing Record 36 of Set 7 | roros
# Processing Record 37 of Set 7 | sendafa
# Processing Record 38 of Set 7 | pingliang
# Processing Record 39 of Set 7 | martinsicuro
# Processing Record 40 of Set 7 | mahebourg
# Processing Record 41 of Set 7 | fernie
# Processing Record 42 of Set 7 | moen
# Processing Record 43 of Set 7 | andenes
# Processing Record 44 of Set 7 | hostotipaquillo
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | coquimbo
# Processing Record 47 of Set 7 | mullaitivu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 48 of Set 7 | naihati
# Processing Record 49 of Set 7 | great yarmouth
# Processing Record 50 of Set 7 | aksha
# Processing Record 1 of Set 8 | pontiac
# Processing Record 2 of Set 8 | korla
# Processing Record 3 of Set 8 | luwuk
# Processing Record 4 of Set 8 | huaidian
# Processing Record 5 of Set 8 | seoul
# Processing Record 6 of Set 8 | tornio
# Processing Record 7 of Set 8 | kaitangata
# Processing Record 8 of Set 8 | jiddah
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 9 of Set 8 | litovko
# Processing Record 10 of Set 8 | skogn
# Processing Record 11 of Set 8 | xining
# Processing Record 12 of Set 8 | bam
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | aklavik
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | antalaha
# Processing Record 17 of Set 8 | pavlovka
# Processing Record 18 of Set 8 | nizhneyansk
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 19 of Set 8 | tevriz
# Processing Record 20 of Set 8 | nanortalik
# Processing Record 21 of Set 8 | husavik
# Processing Record 22 of Set 8 | fairbanks
# Processing Record 23 of Set 8 | khromtau
# Processing Record 24 of Set 8 | karasburg
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | rudsar
# Processing Record 27 of Set 8 | san juan
# Processing Record 28 of Set 8 | sasovo
# Processing Record 29 of Set 8 | coahuayana
# Processing Record 30 of Set 8 | grand river south east
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 31 of Set 8 | saint george
# Processing Record 32 of Set 8 | vanimo
# Processing Record 33 of Set 8 | north bend
# Processing Record 34 of Set 8 | lufilufi
# Processing Record 35 of Set 8 | komsomolskiy
# Processing Record 36 of Set 8 | guinabsan
# Processing Record 37 of Set 8 | lancaster
# Processing Record 38 of Set 8 | sestri levante
# Processing Record 39 of Set 8 | hailar
# Processing Record 40 of Set 8 | alikalia
# Processing Record 41 of Set 8 | kosa
# Processing Record 42 of Set 8 | polyarnyy
# Processing Record 43 of Set 8 | onega
# Processing Record 44 of Set 8 | belmonte
# Processing Record 45 of Set 8 | junin
# Processing Record 46 of Set 8 | magway
# Processing Record 47 of Set 8 | mount isa
# Processing Record 48 of Set 8 | zhangjiakou
# Processing Record 49 of Set 8 | emirdag
# Processing Record 50 of Set 8 | morondava
# Processing Record 1 of Set 9 | buala
# Processing Record 2 of Set 9 | pangai
# Processing Record 3 of Set 9 | kendal
# Processing Record 4 of Set 9 | camocim
# Processing Record 5 of Set 9 | charagua
# Processing Record 6 of Set 9 | alofi
# Processing Record 7 of Set 9 | taupo
# Processing Record 8 of Set 9 | college
# Processing Record 9 of Set 9 | saryozek
# Processing Record 10 of Set 9 | bulawayo
# Processing Record 11 of Set 9 | bilma
# Processing Record 12 of Set 9 | lohja
# Processing Record 13 of Set 9 | buraydah
# Processing Record 14 of Set 9 | ziyang
# Processing Record 15 of Set 9 | gigmoto
# Processing Record 16 of Set 9 | mayo
# Processing Record 17 of Set 9 | tasbuget
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 18 of Set 9 | smithers
# Processing Record 19 of Set 9 | nome
# Processing Record 20 of Set 9 | lubao
# Processing Record 21 of Set 9 | saleaula
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 22 of Set 9 | lerwick
# Processing Record 23 of Set 9 | zabol
# Processing Record 24 of Set 9 | camp verde
# Processing Record 25 of Set 9 | rocha
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | luena
# Processing Record 28 of Set 9 | tsumeb
# Processing Record 29 of Set 9 | simoes
# Processing Record 30 of Set 9 | labuan
# Processing Record 31 of Set 9 | bakchar
# Processing Record 32 of Set 9 | le vauclin
# Processing Record 33 of Set 9 | mrirt
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 34 of Set 9 | tsihombe
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 35 of Set 9 | tulsa
# Processing Record 36 of Set 9 | labuhan
# Processing Record 37 of Set 9 | tigil
# Processing Record 38 of Set 9 | barabash
# Processing Record 39 of Set 9 | kusti
# Processing Record 40 of Set 9 | malwan
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 41 of Set 9 | pahrump
# Processing Record 42 of Set 9 | lubu
# Processing Record 43 of Set 9 | kon tum
# Processing Record 44 of Set 9 | saint-pierre
# Processing Record 45 of Set 9 | tadepallegudem
# Processing Record 46 of Set 9 | hoshcha
# Processing Record 47 of Set 9 | tabialan
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 48 of Set 9 | road town
# Processing Record 49 of Set 9 | nabire
# Processing Record 50 of Set 9 | ambilobe
# Processing Record 1 of Set 10 | taywarah
# Processing Record 2 of Set 10 | orcopampa
# Processing Record 3 of Set 10 | bafra
# Processing Record 4 of Set 10 | grootfontein
# Processing Record 5 of Set 10 | homer
# Processing Record 6 of Set 10 | strandby
# Processing Record 7 of Set 10 | ulladulla
# Processing Record 8 of Set 10 | tual
# Processing Record 9 of Set 10 | saint-leu
# Processing Record 10 of Set 10 | kassala
# Processing Record 11 of Set 10 | macaboboni
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 12 of Set 10 | zhezkazgan
# Processing Record 13 of Set 10 | salur
# Processing Record 14 of Set 10 | pisco
# Processing Record 15 of Set 10 | jinchang
# Processing Record 16 of Set 10 | atasu
# Processing Record 17 of Set 10 | savalou
# Processing Record 18 of Set 10 | pemangkat
# Processing Record 19 of Set 10 | ojinaga
# Processing Record 20 of Set 10 | broome
# Processing Record 21 of Set 10 | kralendijk
# Processing Record 22 of Set 10 | bokspits
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 23 of Set 10 | maloy
# Processing Record 24 of Set 10 | apahida
# Processing Record 25 of Set 10 | kaeo
# Processing Record 26 of Set 10 | boyolangu
# Processing Record 27 of Set 10 | troitskoye
# Processing Record 28 of Set 10 | touros
# Processing Record 29 of Set 10 | manggar
# Processing Record 30 of Set 10 | skjervoy
# Processing Record 31 of Set 10 | parabel
# Processing Record 32 of Set 10 | qandala
# Processing Record 33 of Set 10 | erenhot
# Processing Record 34 of Set 10 | roshchino
# Processing Record 35 of Set 10 | jalu
# Processing Record 36 of Set 10 | ustka
# Processing Record 37 of Set 10 | santa rosa
# Processing Record 38 of Set 10 | satitoa
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 39 of Set 10 | maldonado
# Processing Record 40 of Set 10 | povenets
# Processing Record 41 of Set 10 | ramat yishay
# Processing Record 42 of Set 10 | baykit
# Processing Record 43 of Set 10 | beloha
# Processing Record 44 of Set 10 | half moon bay
# Processing Record 45 of Set 10 | georgiyevka
# Processing Record 46 of Set 10 | zwedru
# Processing Record 47 of Set 10 | zhigansk
# Processing Record 48 of Set 10 | vagay
# Processing Record 49 of Set 10 | srednekolymsk
# Processing Record 50 of Set 10 | halifax
# Processing Record 1 of Set 11 | mizan teferi
# Processing Record 2 of Set 11 | egvekinot
# Processing Record 3 of Set 11 | labutta
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 4 of Set 11 | abha
# Processing Record 5 of Set 11 | bohl-iggelheim
# Processing Record 6 of Set 11 | owando
# Processing Record 7 of Set 11 | kedougou
# Processing Record 8 of Set 11 | victoria point
# Processing Record 9 of Set 11 | matara
# Processing Record 10 of Set 11 | seymchan
# Processing Record 11 of Set 11 | fernandopolis
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | acarau
# Processing Record 14 of Set 11 | santa catarina de tepehuanes
# Processing Record 15 of Set 11 | buckeye
# Processing Record 16 of Set 11 | meadow lake
# Processing Record 17 of Set 11 | meulaboh
# Processing Record 18 of Set 11 | benalla
# Processing Record 19 of Set 11 | matagami
# Processing Record 20 of Set 11 | banda aceh
# Processing Record 21 of Set 11 | khani
# Processing Record 22 of Set 11 | llata
# Processing Record 23 of Set 11 | ballina
# Processing Record 24 of Set 11 | sovetskiy
# Processing Record 25 of Set 11 | yarada
# Processing Record 26 of Set 11 | naron
# Processing Record 27 of Set 11 | monze
# Processing Record 28 of Set 11 | la tuque
# Processing Record 29 of Set 11 | waipawa
# Processing Record 30 of Set 11 | yar-sale
# Processing Record 31 of Set 11 | eyl
# Processing Record 32 of Set 11 | hermosillo
# Processing Record 33 of Set 11 | pangnirtung
# Processing Record 34 of Set 11 | la rioja
# Processing Record 35 of Set 11 | nueva concepcion
# Processing Record 36 of Set 11 | mocambique
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 37 of Set 11 | hare bay
# Processing Record 38 of Set 11 | haines junction
# Processing Record 39 of Set 11 | solin
# Processing Record 40 of Set 11 | ampanihy
# Processing Record 41 of Set 11 | klaksvik
# Processing Record 42 of Set 11 | ogulin
# Processing Record 43 of Set 11 | muisne
# Processing Record 44 of Set 11 | biltine
# Processing Record 45 of Set 11 | joshimath
# Processing Record 46 of Set 11 | zolotinka
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 47 of Set 11 | krasni okny
# Processing Record 48 of Set 11 | ourinhos
# Processing Record 49 of Set 11 | honningsvag
# Processing Record 50 of Set 11 | de aar
# Processing Record 1 of Set 12 | ceska trebova
# Processing Record 2 of Set 12 | katobu
# Processing Record 3 of Set 12 | falealupo
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 4 of Set 12 | orsha
# Processing Record 5 of Set 12 | puerto carreno
# Processing Record 6 of Set 12 | moanda
# Processing Record 7 of Set 12 | bilibino
# Processing Record 8 of Set 12 | zaozerne
# Processing Record 9 of Set 12 | camacha
# Processing Record 10 of Set 12 | aswan
# Processing Record 11 of Set 12 | somerville
# Processing Record 12 of Set 12 | raudeberg
# Processing Record 13 of Set 12 | mazamari
# Processing Record 14 of Set 12 | champerico
# Processing Record 15 of Set 12 | talnakh
# Processing Record 16 of Set 12 | ekibastuz
# Processing Record 17 of Set 12 | nautla
# Processing Record 18 of Set 12 | hammerfest
# Processing Record 19 of Set 12 | zavitinsk
# Processing Record 20 of Set 12 | claver
# Processing Record 21 of Set 12 | katangli
# Processing Record 22 of Set 12 | sao felix do xingu
# Processing Record 23 of Set 12 | flinders
# Processing Record 24 of Set 12 | greencastle
# Processing Record 25 of Set 12 | bitlis
# Processing Record 26 of Set 12 | sept-iles
# Processing Record 27 of Set 12 | fort saint james
# Processing Record 28 of Set 12 | wajima
# Processing Record 29 of Set 12 | puerto madryn
# Processing Record 30 of Set 12 | gramsh
# Processing Record 31 of Set 12 | malinyi
# Processing Record 32 of Set 12 | novikovo
# Processing Record 33 of Set 12 | port-cartier
# Processing Record 34 of Set 12 | merauke
# Processing Record 35 of Set 12 | merrill
# Processing Record 36 of Set 12 | kroderen
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 37 of Set 12 | makung
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 38 of Set 12 | sulangan
# Processing Record 39 of Set 12 | abu zabad
# Processing Record 40 of Set 12 | mandera
# Processing Record 41 of Set 12 | rawannawi
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 42 of Set 12 | tahe
# Processing Record 43 of Set 12 | waingapu
# Processing Record 44 of Set 12 | talcahuano
# Processing Record 45 of Set 12 | tolbazy
# Processing Record 46 of Set 12 | leshukonskoye
# Processing Record 47 of Set 12 | whitehorse
# Processing Record 48 of Set 12 | masjed-e soleyman
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 49 of Set 12 | magadi
# Processing Record 50 of Set 12 | tamale
# Processing Record 1 of Set 13 | mareeba
# Processing Record 2 of Set 13 | rupert
# Processing Record 3 of Set 13 | kumbo
# Processing Record 4 of Set 13 | alotau
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 5 of Set 13 | moranbah
# Processing Record 6 of Set 13 | desaguadero
# Processing Record 7 of Set 13 | lagoa
# Processing Record 8 of Set 13 | sur
# Processing Record 9 of Set 13 | faya
# Processing Record 10 of Set 13 | semey
# Processing Record 11 of Set 13 | kamenka
# Processing Record 12 of Set 13 | bend
# Processing Record 13 of Set 13 | pucallpa
# Processing Record 14 of Set 13 | staryy nadym
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | yabrud
# Processing Record 17 of Set 13 | jaru
# Processing Record 18 of Set 13 | rundu
# Processing Record 19 of Set 13 | hyderabad
# Processing Record 20 of Set 13 | afmadu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 21 of Set 13 | ginda
# Processing Record 22 of Set 13 | caconda
# Processing Record 23 of Set 13 | huazolotitlan
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 24 of Set 13 | codrington
# Processing Record 25 of Set 13 | mergui
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 26 of Set 13 | barra
# Processing Record 27 of Set 13 | kaniama
# Processing Record 28 of Set 13 | kudahuvadhoo
# Processing Record 29 of Set 13 | itoman
# Processing Record 30 of Set 13 | manavalakurichi
# Processing Record 31 of Set 13 | christchurch
# Processing Record 32 of Set 13 | bijela
# Processing Record 33 of Set 13 | altay
# Processing Record 34 of Set 13 | spirit river
# Processing Record 35 of Set 13 | dong hoi
# Processing Record 36 of Set 13 | bhag
# Processing Record 37 of Set 13 | vila franca do campo
# Processing Record 38 of Set 13 | ponnani
# Processing Record 39 of Set 13 | almaznyy
# Processing Record 40 of Set 13 | greytown
# Processing Record 41 of Set 13 | marsh harbour
# Processing Record 42 of Set 13 | muros
# Processing Record 43 of Set 13 | turbat
# Processing Record 44 of Set 13 | chulman
# Processing Record 45 of Set 13 | yeppoon
# Processing Record 46 of Set 13 | kondinskoye
# Processing Record 47 of Set 13 | iskateley
# Processing Record 48 of Set 13 | batagay-alyta
# Processing Record 49 of Set 13 | miri
# Processing Record 50 of Set 13 | silver city
# Processing Record 1 of Set 14 | colomi
# Processing Record 2 of Set 14 | trelew
# Processing Record 3 of Set 14 | santa cruz
# Processing Record 4 of Set 14 | hashtrud
# Processing Record 5 of Set 14 | nouadhibou
# Processing Record 6 of Set 14 | arona
# Processing Record 7 of Set 14 | henties bay
# Processing Record 8 of Set 14 | severobaykalsk
# Processing Record 9 of Set 14 | bara
# Processing Record 10 of Set 14 | bethel
# Processing Record 11 of Set 14 | hukuntsi
# Processing Record 12 of Set 14 | karamea
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 13 of Set 14 | san lawrenz
# Processing Record 14 of Set 14 | ulverstone
# Processing Record 15 of Set 14 | zverinogolovskoye
# Processing Record 16 of Set 14 | lukovetskiy
# Processing Record 17 of Set 14 | tidore
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 18 of Set 14 | marystown
# Processing Record 19 of Set 14 | yerofey pavlovich
# Processing Record 20 of Set 14 | mudgee
# Processing Record 21 of Set 14 | terney
# Processing Record 22 of Set 14 | calvia
# Processing Record 23 of Set 14 | rize
# Processing Record 24 of Set 14 | wana
# Processing Record 25 of Set 14 | bundaberg
# Processing Record 26 of Set 14 | sakakah
# Processing Record 27 of Set 14 | vila velha
# Processing Record 28 of Set 14 | san nicolas
# Processing Record 29 of Set 14 | consett
# Processing Record 30 of Set 14 | dolores
# Processing Record 31 of Set 14 | okha
# Processing Record 32 of Set 14 | launceston
# Processing Record 33 of Set 14 | brownwood
# Processing Record 34 of Set 14 | ciras
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 35 of Set 14 | tomohon
# Processing Record 36 of Set 14 | tymovskoye
# Processing Record 37 of Set 14 | mutare
# Processing Record 38 of Set 14 | rizhao
# Processing Record 39 of Set 14 | kharp
# Processing Record 40 of Set 14 | bridgetown
# Processing Record 41 of Set 14 | maloshuyka
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 42 of Set 14 | cantaura
# Processing Record 43 of Set 14 | warqla
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 44 of Set 14 | chiang kham
# Processing Record 45 of Set 14 | lesnoye
# Processing Record 46 of Set 14 | ca mau
# Processing Record 47 of Set 14 | matam
# Processing Record 48 of Set 14 | yorkton
# Processing Record 49 of Set 14 | berlevag
# Processing Record 50 of Set 14 | tostamaa
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 1 of Set 15 | isla vista
# Processing Record 2 of Set 15 | marawi
# Processing Record 3 of Set 15 | arman
# Processing Record 4 of Set 15 | newton
# Processing Record 5 of Set 15 | murray bridge
# Processing Record 6 of Set 15 | shimoda
# Processing Record 7 of Set 15 | roblin
# Processing Record 8 of Set 15 | areia branca
# Processing Record 9 of Set 15 | lahijan
# Processing Record 10 of Set 15 | nadym
# Processing Record 11 of Set 15 | caucasia
# Processing Record 12 of Set 15 | letpadan
# Processing Record 13 of Set 15 | martapura
# Processing Record 14 of Set 15 | emerald
# Processing Record 15 of Set 15 | glossa
# Processing Record 16 of Set 15 | batagay
# Processing Record 17 of Set 15 | agadez
# Processing Record 18 of Set 15 | anahuac
# Processing Record 19 of Set 15 | maun
# Processing Record 20 of Set 15 | cesenatico
# Processing Record 21 of Set 15 | sambava
# Processing Record 22 of Set 15 | havoysund
# Processing Record 23 of Set 15 | cap-aux-meules
# Processing Record 24 of Set 15 | phan thiet
# Processing Record 25 of Set 15 | mogadishu
# Processing Record 26 of Set 15 | shaunavon
# Processing Record 27 of Set 15 | vostok
# Processing Record 28 of Set 15 | samalaeulu
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 29 of Set 15 | suining
# Processing Record 30 of Set 15 | nago
# Processing Record 31 of Set 15 | zhanakorgan
# Processing Record 32 of Set 15 | kloulklubed
# Processing Record 33 of Set 15 | rio grande
# Processing Record 34 of Set 15 | calera
# Processing Record 35 of Set 15 | lakes entrance
# Processing Record 36 of Set 15 | dolinsk
# Processing Record 37 of Set 15 | tutoia
# Processing Record 38 of Set 15 | kununurra
# Processing Record 39 of Set 15 | babaeski
# Processing Record 40 of Set 15 | mwinilunga
# Processing Record 41 of Set 15 | itarema
# Processing Record 42 of Set 15 | nogliki
# Processing Record 43 of Set 15 | johi
# Processing Record 44 of Set 15 | vermilion
# Processing Record 45 of Set 15 | lolua
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 46 of Set 15 | kota belud
# Processing Record 47 of Set 15 | invermere
# Processing Record 48 of Set 15 | rorvik
# Processing Record 49 of Set 15 | umiray
# Processing Record 50 of Set 15 | barawe
# 'coord'
# No weather data found. Skipping a city...
# Processing Record 1 of Set 16 | van
# Processing Record 2 of Set 16 | ust-kut
# Processing Record 3 of Set 16 | bagdarin
# Processing Record 4 of Set 16 | vung tau
# Processing Record 5 of Set 16 | camara de lobos
# Processing Record 6 of Set 16 | ndjole
# Processing Record 7 of Set 16 | eydhafushi
# Processing Record 8 of Set 16 | tuy hoa
# Processing Record 9 of Set 16 | palembang
# Processing Record 10 of Set 16 | walvis bay
# Processing Record 11 of Set 16 | cajnice
# Processing Record 12 of Set 16 | subaytilah
# 'coord'
# No weather data found. Skipping a city...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 57,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 5.01,
#   'Country': 'NZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Searcy',
#   'Lat': 35.2506,
#   'Lng': -91.7363,
#   'Max Temp': 66.99,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 80.01,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 5.99,
#   'Country': 'MU',
#   'Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -26.01,
#   'Humidity': 98,
#   'Cloudiness': 80,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Wajid',
#   'Lat': 3.8093,
#   'Lng': 43.2471,
#   'Max Temp': 81.34,
#   'Humidity': 57,
#   'Cloudiness': 97,
#   'Wind Speed': 9.86,
#   'Country': 'SO',
#   'Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 57.63,
#   'Humidity': 68,
#   'Cloudiness': 5,
#   'Wind Speed': 13.15,
#   'Country': 'CL',
#   'Description': 'clear sky'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 36.14,
#   'Humidity': 74,
#   'Cloudiness': 85,
#   'Wind Speed': 32.57,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 97.03,
#   'Humidity': 9,
#   'Cloudiness': 3,
#   'Wind Speed': 10.69,
#   'Country': 'ML',
#   'Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 53.6,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'AR',
#   'Description': 'scattered clouds'},
#  {'City': 'Rzhev',
#   'Lat': 56.2624,
#   'Lng': 34.3282,
#   'Max Temp': 43.32,
#   'Humidity': 63,
#   'Cloudiness': 25,
#   'Wind Speed': 11.88,
#   'Country': 'RU',
#   'Description': 'scattered clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 80.01,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'MY',
#   'Description': 'light rain'},
#  {'City': 'Shahjahanpur',
#   'Lat': 27.8833,
#   'Lng': 79.9167,
#   'Max Temp': 79.81,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 6.31,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'AR',
#   'Description': 'broken clouds'},
#  {'City': 'Sao Sebastiao',
#   'Lat': -23.76,
#   'Lng': -45.4097,
#   'Max Temp': 81.39,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 4.74,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -18.33,
#   'Humidity': 99,
#   'Cloudiness': 69,
#   'Wind Speed': 5.39,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 79,
#   'Humidity': 89,
#   'Cloudiness': 28,
#   'Wind Speed': 15.99,
#   'Country': 'EC',
#   'Description': 'scattered clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 60.8,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'ZA',
#   'Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 18.88,
#   'Humidity': 94,
#   'Cloudiness': 56,
#   'Wind Speed': 13.56,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Peniche',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 62.01,
#   'Humidity': 88,
#   'Cloudiness': 52,
#   'Wind Speed': 7,
#   'Country': 'PT',
#   'Description': 'broken clouds'},
#  {'City': 'Mahanoro',
#   'Lat': -19.9,
#   'Lng': 48.8,
#   'Max Temp': 75.83,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'MG',
#   'Description': 'light rain'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 79.07,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 13.82,
#   'Country': 'NC',
#   'Description': 'overcast clouds'},
#  {'City': 'Swellendam',
#   'Lat': -34.0226,
#   'Lng': 20.4417,
#   'Max Temp': 60.8,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'ZA',
#   'Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Description': 'overcast clouds'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 34.41,
#   'Humidity': 88,
#   'Cloudiness': 38,
#   'Wind Speed': 8.97,
#   'Country': 'GL',
#   'Description': 'scattered clouds'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 57.99,
#   'Humidity': 62,
#   'Cloudiness': 94,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Tema',
#   'Lat': 5.667,
#   'Lng': -0.0166,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'GH',
#   'Description': 'scattered clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 33.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 23.02,
#   'Country': 'CA',
#   'Description': 'snow'},
#  {'City': 'Tavda',
#   'Lat': 58.0425,
#   'Lng': 65.2726,
#   'Max Temp': 40.91,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 43,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Description': 'light rain'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 66.29,
#   'Humidity': 61,
#   'Cloudiness': 78,
#   'Wind Speed': 14.32,
#   'Country': 'MX',
#   'Description': 'broken clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 53.6,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Country': 'CL',
#   'Description': 'scattered clouds'},
#  {'City': 'Troitsko-Pechorsk',
#   'Lat': 62.7084,
#   'Lng': 56.1964,
#   'Max Temp': 32.34,
#   'Humidity': 95,
#   'Cloudiness': 7,
#   'Wind Speed': 7.07,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 68.77,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 5.75,
#   'Country': 'ZA',
#   'Description': 'overcast clouds'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 61,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'CK',
#   'Description': 'few clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 64.99,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'AU',
#   'Description': 'light rain'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 53.65,
#   'Humidity': 95,
#   'Cloudiness': 95,
#   'Wind Speed': 3.22,
#   'Country': 'NZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -5.4,
#   'Humidity': 88,
#   'Cloudiness': 14,
#   'Wind Speed': 10.09,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.23,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 11.16,
#   'Country': 'KI',
#   'Description': 'light rain'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 23,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 11.12,
#   'Country': 'RE',
#   'Description': 'light rain'},
#  {'City': 'Nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 10.09,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.56,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 66,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 24.8,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02,
#   'Country': 'SJ',
#   'Description': 'broken clouds'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 52.02,
#   'Humidity': 39,
#   'Cloudiness': 63,
#   'Wind Speed': 10.49,
#   'Country': 'CN',
#   'Description': 'broken clouds'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 82.4,
#   'Humidity': 14,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'SA',
#   'Description': 'few clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 57,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 5.01,
#   'Country': 'NZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 73.4,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Description': 'few clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.77,
#   'Humidity': 67,
#   'Cloudiness': 84,
#   'Wind Speed': 11.88,
#   'Country': 'MV',
#   'Description': 'broken clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 73.4,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 70,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Description': 'light rain'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 62.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'PT',
#   'Description': 'broken clouds'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': -1.66,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 22.01,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 78.75,
#   'Humidity': 71,
#   'Cloudiness': 2,
#   'Wind Speed': 9.51,
#   'Country': 'PF',
#   'Description': 'clear sky'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 32.16,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 17,
#   'Country': 'RU',
#   'Description': 'snow'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 66.2,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Sarishabari',
#   'Lat': 24.7333,
#   'Lng': 89.8333,
#   'Max Temp': 78.82,
#   'Humidity': 72,
#   'Cloudiness': 6,
#   'Wind Speed': 14.07,
#   'Country': 'BD',
#   'Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'OM',
#   'Description': 'clear sky'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 84.2,
#   'Humidity': 39,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 61,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 0.27,
#   'Country': 'ZA',
#   'Description': 'overcast clouds'},
#  {'City': 'Bagar',
#   'Lat': 28.1874,
#   'Lng': 75.5005,
#   'Max Temp': 76.93,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 3.94,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 41,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'GB',
#   'Description': 'light rain'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 75,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Dale',
#   'Lat': 38.1689,
#   'Lng': -86.99,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Iberia',
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp': 81,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 7.23,
#   'Country': 'US',
#   'Description': 'broken clouds'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Description': 'mist'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 7.47,
#   'Country': 'US',
#   'Description': 'snow'},
#  {'City': 'Zenzeli',
#   'Lat': 45.9241,
#   'Lng': 47.0474,
#   'Max Temp': 57.99,
#   'Humidity': 57,
#   'Cloudiness': 69,
#   'Wind Speed': 8.66,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 81.9,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 10.54,
#   'Country': 'PF',
#   'Description': 'overcast clouds'},
#  {'City': 'Price',
#   'Lat': 39.5994,
#   'Lng': -110.8107,
#   'Max Temp': 57.2,
#   'Humidity': 14,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Xiaoweizhai',
#   'Lat': 26.1903,
#   'Lng': 107.5125,
#   'Max Temp': 51.98,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Country': 'CN',
#   'Description': 'overcast clouds'},
#  {'City': 'Nacala',
#   'Lat': -14.5428,
#   'Lng': 40.6728,
#   'Max Temp': 74.1,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 6.33,
#   'Country': 'MZ',
#   'Description': 'moderate rain'},
#  {'City': 'Canutama',
#   'Lat': -6.5339,
#   'Lng': -64.3831,
#   'Max Temp': 80.55,
#   'Humidity': 90,
#   'Cloudiness': 73,
#   'Wind Speed': 4.43,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 77.18,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 15.7,
#   'Country': 'VU',
#   'Description': 'overcast clouds'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 83.59,
#   'Humidity': 70,
#   'Cloudiness': 93,
#   'Wind Speed': 12.19,
#   'Country': 'MV',
#   'Description': 'overcast clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 31,
#   'Wind Speed': 11.68,
#   'Country': 'IL',
#   'Description': 'scattered clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 20.59,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Country': 'GL',
#   'Description': 'overcast clouds'},
#  {'City': 'Sturgis',
#   'Lat': 41.7992,
#   'Lng': -85.4192,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Mackenzie',
#   'Lat': 55.2999,
#   'Lng': -123.1698,
#   'Max Temp': 30.2,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Description': 'scattered clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 77,
#   'Humidity': 47,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'AU',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 58.05,
#   'Humidity': 63,
#   'Cloudiness': 95,
#   'Wind Speed': 14.88,
#   'Country': 'AU',
#   'Description': 'overcast clouds'},
#  {'City': 'Yamada',
#   'Lat': 39.4667,
#   'Lng': 141.95,
#   'Max Temp': 37.6,
#   'Humidity': 75,
#   'Cloudiness': 22,
#   'Wind Speed': 4.99,
#   'Country': 'JP',
#   'Description': 'few clouds'},
#  {'City': 'Dickinson',
#   'Lat': 29.4608,
#   'Lng': -95.0513,
#   'Max Temp': 80.01,
#   'Humidity': 47,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 36.93,
#   'Humidity': 65,
#   'Cloudiness': 47,
#   'Wind Speed': 7.94,
#   'Country': 'RU',
#   'Description': 'scattered clouds'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 42.8,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Description': 'light rain'},
#  {'City': 'Kongwa',
#   'Lat': -6.2,
#   'Lng': 36.4167,
#   'Max Temp': 64.99,
#   'Humidity': 94,
#   'Cloudiness': 87,
#   'Wind Speed': 4.03,
#   'Country': 'TZ',
#   'Description': 'light rain'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Description': 'light rain'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -16.6,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 77,
#   'Humidity': 60,
#   'Cloudiness': 6,
#   'Wind Speed': 9.71,
#   'Country': 'CV',
#   'Description': 'clear sky'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 56.91,
#   'Humidity': 33,
#   'Cloudiness': 51,
#   'Wind Speed': 7.31,
#   'Country': 'CN',
#   'Description': 'broken clouds'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 55.4,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 7.52,
#   'Country': 'US',
#   'Description': 'broken clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 28.99,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.21,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 57,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'ID',
#   'Description': 'scattered clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 61,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'ZA',
#   'Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 39.2,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'JP',
#   'Description': 'few clouds'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'AO',
#   'Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 4.62,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 5.77,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 68.88,
#   'Humidity': 68,
#   'Cloudiness': 30,
#   'Wind Speed': 4.47,
#   'Country': 'IN',
#   'Description': 'moderate rain'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 28.36,
#   'Humidity': 75,
#   'Cloudiness': 93,
#   'Wind Speed': 17.38,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Poltava',
#   'Lat': 49.5937,
#   'Lng': 34.5407,
#   'Max Temp': 45.55,
#   'Humidity': 48,
#   'Cloudiness': 39,
#   'Wind Speed': 5.88,
#   'Country': 'UA',
#   'Description': 'scattered clouds'},
#  {'City': 'Vysokogornyy',
#   'Lat': 50.1167,
#   'Lng': 139.15,
#   'Max Temp': 24.39,
#   'Humidity': 85,
#   'Cloudiness': 11,
#   'Wind Speed': 3.2,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 32.68,
#   'Humidity': 63,
#   'Cloudiness': 99,
#   'Wind Speed': 7.9,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 72.18,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 7.05,
#   'Country': 'MZ',
#   'Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'AU',
#   'Description': 'scattered clouds'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 32,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 75.54,
#   'Humidity': 82,
#   'Cloudiness': 57,
#   'Wind Speed': 5.59,
#   'Country': 'PH',
#   'Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Country': 'GL',
#   'Description': 'broken clouds'},
#  {'City': 'Porbandar',
#   'Lat': 21.6422,
#   'Lng': 69.6093,
#   'Max Temp': 80.76,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 11.72,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 57.58,
#   'Humidity': 78,
#   'Cloudiness': 33,
#   'Wind Speed': 1.34,
#   'Country': 'TL',
#   'Description': 'scattered clouds'},
#  {'City': 'Angoche',
#   'Lat': -16.2325,
#   'Lng': 39.9086,
#   'Max Temp': 76.17,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 5.7,
#   'Country': 'MZ',
#   'Description': 'light rain'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 84.29,
#   'Humidity': 72,
#   'Cloudiness': 74,
#   'Wind Speed': 9.91,
#   'Country': 'SL',
#   'Description': 'broken clouds'},
#  {'City': 'Saint-Gaudens',
#   'Lat': 43.0833,
#   'Lng': 0.6667,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'FR',
#   'Description': 'few clouds'},
#  {'City': 'Thoen',
#   'Lat': 17.6129,
#   'Lng': 99.2161,
#   'Max Temp': 80.01,
#   'Humidity': 99,
#   'Cloudiness': 75,
#   'Wind Speed': 2.13,
#   'Country': 'TH',
#   'Description': 'broken clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -9.4,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Description': 'light snow'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.55,
#   'Humidity': 75,
#   'Cloudiness': 77,
#   'Wind Speed': 18.63,
#   'Country': 'PF',
#   'Description': 'broken clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 71.6,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -13,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Description': 'few clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 64,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 5.52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 19.82,
#   'Country': 'RU',
#   'Description': 'light snow'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 63.41,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 12.88,
#   'Country': 'CL',
#   'Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 67.64,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'UY',
#   'Description': 'moderate rain'},
#  {'City': 'Lodja',
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp': 73.2,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 3.36,
#   'Country': 'CD',
#   'Description': 'light rain'},
#  {'City': 'Ulaangom',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 32.34,
#   'Humidity': 50,
#   'Cloudiness': 88,
#   'Wind Speed': 14.72,
#   'Country': 'MN',
#   'Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -23.89,
#   'Humidity': 95,
#   'Cloudiness': 8,
#   'Wind Speed': 2.28,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 50,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'JP',
#   'Description': 'few clouds'},
#  {'City': 'Wuhu',
#   'Lat': 31.3366,
#   'Lng': 118.3755,
#   'Max Temp': 57.2,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Description': 'light rain'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 37.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Description': 'broken clouds'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 70,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'AR',
#   'Description': 'light rain'},
#  {'City': 'Mackay',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 13,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Description': 'few clouds'},
#  {'City': 'Udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': -17.39,
#   'Humidity': 100,
#   'Cloudiness': 22,
#   'Wind Speed': 5.82,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 78.8,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'MX',
#   'Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 55.99,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Description': 'few clouds'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 89.44,
#   'Humidity': 57,
#   'Cloudiness': 2,
#   'Wind Speed': 8.43,
#   'Country': 'MX',
#   'Description': 'clear sky'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 64,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Description': 'moderate rain'},
#  {'City': 'Winter Springs',
#   'Lat': 28.6989,
#   'Lng': -81.3081,
#   'Max Temp': 89.01,
#   'Humidity': 40,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Description': 'few clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 62.96,
#   'Humidity': 94,
#   'Cloudiness': 23,
#   'Wind Speed': 0.74,
#   'Country': 'NZ',
#   'Description': 'few clouds'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 73.49,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 68.31,
#   'Humidity': 71,
#   'Cloudiness': 95,
#   'Wind Speed': 6.08,
#   'Country': 'CL',
#   'Description': 'overcast clouds'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 11.83,
#   'Country': 'PF',
#   'Description': 'light rain'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 51.8,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Description': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 62.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'ZA',
#   'Description': 'broken clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 57.99,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 6.01,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Description': 'few clouds'},
#  {'City': 'Cobourg',
#   'Lat': 50.2667,
#   'Lng': 10.9667,
#   'Max Temp': 50,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'DE',
#   'Description': 'overcast clouds'},
#  {'City': 'Morgan City',
#   'Lat': 29.6994,
#   'Lng': -91.2068,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Description': 'scattered clouds'},
#  {'City': 'Anjar',
#   'Lat': 23.1333,
#   'Lng': 70.0167,
#   'Max Temp': 83.19,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 12.01,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Muzhi',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 30.15,
#   'Humidity': 85,
#   'Cloudiness': 14,
#   'Wind Speed': 9.95,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 8.32,
#   'Country': 'RE',
#   'Description': 'light rain'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 3.2,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Mikuni',
#   'Lat': 36.2171,
#   'Lng': 136.1519,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'JP',
#   'Description': 'clear sky'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 83.43,
#   'Humidity': 67,
#   'Cloudiness': 45,
#   'Wind Speed': 2.46,
#   'Country': 'MV',
#   'Description': 'scattered clouds'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 30.2,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'FO',
#   'Description': 'light snow'},
#  {'City': 'Yeniseysk',
#   'Lat': 58.4497,
#   'Lng': 92.1703,
#   'Max Temp': 24.94,
#   'Humidity': 95,
#   'Cloudiness': 12,
#   'Wind Speed': 2.1,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 81,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MX',
#   'Description': 'scattered clouds'},
#  {'City': 'Perth Amboy',
#   'Lat': 40.5068,
#   'Lng': -74.2654,
#   'Max Temp': 68,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Description': 'broken clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 37,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Description': 'scattered clouds'},
#  {'City': 'Ambulu',
#   'Lat': -8.345,
#   'Lng': 113.6058,
#   'Max Temp': 76.33,
#   'Humidity': 90,
#   'Cloudiness': 31,
#   'Wind Speed': 2.77,
#   'Country': 'ID',
#   'Description': 'scattered clouds'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Description': 'scattered clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 64.99,
#   'Humidity': 70,
#   'Cloudiness': 53,
#   'Wind Speed': 3,
#   'Country': 'PT',
#   'Description': 'broken clouds'},
#  {'City': 'Anderson',
#   'Lat': 34.5334,
#   'Lng': -82.6499,
#   'Max Temp': 68,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Description': 'light rain'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'TO',
#   'Description': 'few clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.08,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'ID',
#   'Description': 'overcast clouds'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 97.38,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 6.24,
#   'Country': 'ML',
#   'Description': 'clear sky'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 76.62,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'ID',
#   'Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -33.03,
#   'Humidity': 100,
#   'Cloudiness': 85,
#   'Wind Speed': 3.53,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Redmond',
#   'Lat': 47.674,
#   'Lng': -122.1215,
#   'Max Temp': 46,
#   'Humidity': 72,
#   'Cloudiness': 85,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 57.2,
#   'Humidity': 88,
#   'Cloudiness': 78,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Description': 'broken clouds'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 79.36,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.44,
#   'Country': 'AO',
#   'Description': 'overcast clouds'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -10.07,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 7.43,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Ihosy',
#   'Lat': -22.4,
#   'Lng': 46.1167,
#   'Max Temp': 69.12,
#   'Humidity': 85,
#   'Cloudiness': 66,
#   'Wind Speed': 5.55,
#   'Country': 'MG',
#   'Description': 'broken clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 78.51,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.4,
#   'Country': 'PG',
#   'Description': 'light rain'},
#  {'City': 'Bosaso',
#   'Lat': 11.2842,
#   'Lng': 49.1816,
#   'Max Temp': 80.26,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.03,
#   'Country': 'SO',
#   'Description': 'clear sky'},
#  {'City': 'Suleja',
#   'Lat': 9.1758,
#   'Lng': 7.1808,
#   'Max Temp': 95,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'NG',
#   'Description': 'few clouds'},
#  {'City': 'Sarangani',
#   'Lat': 5.4033,
#   'Lng': 125.4636,
#   'Max Temp': 82.58,
#   'Humidity': 74,
#   'Cloudiness': 47,
#   'Wind Speed': 8.23,
#   'Country': 'PH',
#   'Description': 'scattered clouds'},
#  {'City': 'Sabang',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 83.86,
#   'Humidity': 70,
#   'Cloudiness': 70,
#   'Wind Speed': 8.23,
#   'Country': 'ID',
#   'Description': 'broken clouds'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 79.32,
#   'Humidity': 80,
#   'Cloudiness': 18,
#   'Wind Speed': 8.1,
#   'Country': 'AO',
#   'Description': 'few clouds'},
#  {'City': 'San Esteban',
#   'Lat': 15.2,
#   'Lng': -85.75,
#   'Max Temp': 93.2,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'HN',
#   'Description': 'scattered clouds'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 83.03,
#   'Humidity': 65,
#   'Cloudiness': 13,
#   'Wind Speed': 14.52,
#   'Country': 'SO',
#   'Description': 'few clouds'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -6.56,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 12.37,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 80.01,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Description': 'scattered clouds'},
#  {'City': 'Ammon',
#   'Lat': 43.4696,
#   'Lng': -111.9666,
#   'Max Temp': 57,
#   'Humidity': 28,
#   'Cloudiness': 1,
#   'Wind Speed': 28.77,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Description': 'few clouds'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': -0.4,
#   'Humidity': 60,
#   'Cloudiness': 93,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Kurkino',
#   'Lat': 53.4257,
#   'Lng': 38.6582,
#   'Max Temp': 42.53,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 0.74,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Lethem',
#   'Lat': 3.3803,
#   'Lng': -59.7968,
#   'Max Temp': 89.08,
#   'Humidity': 53,
#   'Cloudiness': 85,
#   'Wind Speed': 6.31,
#   'Country': 'GY',
#   'Description': 'overcast clouds'},
#  {'City': 'Zaysan',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 41.27,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 4.81,
#   'Country': 'KZ',
#   'Description': 'clear sky'},
#  {'City': 'Misratah',
#   'Lat': 32.3754,
#   'Lng': 15.0925,
#   'Max Temp': 59.94,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 20.29,
#   'Country': 'LY',
#   'Description': 'overcast clouds'},
#  {'City': 'Denpasar',
#   'Lat': -8.65,
#   'Lng': 115.2167,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'ID',
#   'Description': 'few clouds'},
#  {'City': 'Yantal',
#   'Lat': 56.8471,
#   'Lng': 105.2542,
#   'Max Temp': 9.82,
#   'Humidity': 97,
#   'Cloudiness': 71,
#   'Wind Speed': 2.8,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 80.4,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 10.71,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'MG',
#   'Description': 'light rain'},
#  {'City': 'Pizhanka',
#   'Lat': 57.4604,
#   'Lng': 48.542,
#   'Max Temp': 33.76,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 78.4,
#   'Humidity': 38,
#   'Cloudiness': 2,
#   'Wind Speed': 2.08,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 79.93,
#   'Humidity': 70,
#   'Cloudiness': 23,
#   'Wind Speed': 10.92,
#   'Country': 'SO',
#   'Description': 'few clouds'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 85.5,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 3.27,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Ileza',
#   'Lat': 61.0533,
#   'Lng': 43.9002,
#   'Max Temp': 37.15,
#   'Humidity': 78,
#   'Cloudiness': 78,
#   'Wind Speed': 12.53,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 78.37,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'PG',
#   'Description': 'light rain'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 83.97,
#   'Humidity': 70,
#   'Cloudiness': 37,
#   'Wind Speed': 9.06,
#   'Country': 'BR',
#   'Description': 'scattered clouds'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 23.41,
#   'Humidity': 95,
#   'Cloudiness': 81,
#   'Wind Speed': 6.62,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 46,
#   'Humidity': 69,
#   'Cloudiness': 37,
#   'Wind Speed': 8.01,
#   'Country': 'GB',
#   'Description': 'scattered clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 33.42,
#   'Humidity': 41,
#   'Cloudiness': 2,
#   'Wind Speed': 4.7,
#   'Country': 'IS',
#   'Description': 'clear sky'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Description': 'moderate rain'},
#  {'City': 'Vutcani',
#   'Lat': 46.4667,
#   'Lng': 27.9667,
#   'Max Temp': 45.57,
#   'Humidity': 47,
#   'Cloudiness': 2,
#   'Wind Speed': 7.02,
#   'Country': 'RO',
#   'Description': 'light rain'},
#  {'City': 'Oistins',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'BB',
#   'Description': 'volcanic ash'},
#  {'City': 'Nampula',
#   'Lat': -15.1165,
#   'Lng': 39.2666,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MZ',
#   'Description': 'broken clouds'},
#  {'City': 'Boguchany',
#   'Lat': 58.3814,
#   'Lng': 97.4531,
#   'Max Temp': 19.08,
#   'Humidity': 93,
#   'Cloudiness': 13,
#   'Wind Speed': 1.16,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 78.01,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'NC',
#   'Description': 'overcast clouds'},
#  {'City': 'Mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 48.99,
#   'Humidity': 81,
#   'Cloudiness': 33,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Description': 'scattered clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 12.2,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Description': 'light snow'},
#  {'City': 'Alugan',
#   'Lat': 12.2188,
#   'Lng': 125.4808,
#   'Max Temp': 78.71,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 10.07,
#   'Country': 'PH',
#   'Description': 'overcast clouds'},
#  {'City': 'Discovery Bay',
#   'Lat': 37.9085,
#   'Lng': -121.6002,
#   'Max Temp': 64.99,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'GF',
#   'Description': 'broken clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 84.2,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'VE',
#   'Description': 'broken clouds'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 57.2,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'FR',
#   'Description': 'clear sky'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'BB',
#   'Description': 'volcanic ash'},
#  {'City': 'Kawalu',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 72.88,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'ID',
#   'Description': 'overcast clouds'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'GA',
#   'Description': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 20.82,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.79,
#   'Country': 'GL',
#   'Description': 'light snow'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 77.63,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 13.18,
#   'Country': 'GW',
#   'Description': 'clear sky'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 44.6,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'GL',
#   'Description': 'few clouds'},
#  {'City': 'Acolla',
#   'Lat': -11.7319,
#   'Lng': -75.5463,
#   'Max Temp': 59.16,
#   'Humidity': 57,
#   'Cloudiness': 96,
#   'Wind Speed': 4.59,
#   'Country': 'PE',
#   'Description': 'overcast clouds'},
#  {'City': 'Omsukchan',
#   'Lat': 62.5333,
#   'Lng': 155.8,
#   'Max Temp': -9.04,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Mariental',
#   'Lat': -24.6333,
#   'Lng': 17.9667,
#   'Max Temp': 80.19,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 7.9,
#   'Country': 'NA',
#   'Description': 'clear sky'},
#  {'City': 'Rawlins',
#   'Lat': 41.7911,
#   'Lng': -107.2387,
#   'Max Temp': 55,
#   'Humidity': 17,
#   'Cloudiness': 1,
#   'Wind Speed': 26.46,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Petatlan',
#   'Lat': 17.5167,
#   'Lng': -101.2667,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'MX',
#   'Description': 'clear sky'},
#  {'City': 'Olovyannaya',
#   'Lat': 50.95,
#   'Lng': 115.5667,
#   'Max Temp': 30.4,
#   'Humidity': 46,
#   'Cloudiness': 21,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Lucea',
#   'Lat': 18.451,
#   'Lng': -78.1736,
#   'Max Temp': 82.99,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'JM',
#   'Description': 'broken clouds'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 72.18,
#   'Humidity': 83,
#   'Cloudiness': 2,
#   'Wind Speed': 10.33,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 64,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 5.99,
#   'Country': 'AR',
#   'Description': 'overcast clouds'},
#  {'City': 'Knysna',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 68.77,
#   'Humidity': 47,
#   'Cloudiness': 2,
#   'Wind Speed': 7.74,
#   'Country': 'YE',
#   'Description': 'clear sky'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 48,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Vredendal',
#   'Lat': -31.6683,
#   'Lng': 18.5012,
#   'Max Temp': 68.41,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 6.42,
#   'Country': 'ZA',
#   'Description': 'broken clouds'},
#  {'City': 'Curup',
#   'Lat': -3.4667,
#   'Lng': 102.5333,
#   'Max Temp': 66.36,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 2.44,
#   'Country': 'ID',
#   'Description': 'overcast clouds'},
#  {'City': 'Ngerengere',
#   'Lat': -6.75,
#   'Lng': 38.1167,
#   'Max Temp': 72.57,
#   'Humidity': 95,
#   'Cloudiness': 91,
#   'Wind Speed': 3.53,
#   'Country': 'TZ',
#   'Description': 'light rain'},
#  {'City': 'Yangambi',
#   'Lat': 0.8102,
#   'Lng': 24.4336,
#   'Max Temp': 75.49,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 2.46,
#   'Country': 'CD',
#   'Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 86,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Description': 'few clouds'},
#  {'City': 'Ashqelon',
#   'Lat': 31.6693,
#   'Lng': 34.5715,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 34,
#   'Wind Speed': 14.47,
#   'Country': 'IL',
#   'Description': 'scattered clouds'},
#  {'City': 'Sesheke',
#   'Lat': -17.4759,
#   'Lng': 24.2968,
#   'Max Temp': 68.27,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 6.2,
#   'Country': 'ZM',
#   'Description': 'clear sky'},
#  {'City': 'Port Shepstone',
#   'Lat': -30.7414,
#   'Lng': 30.455,
#   'Max Temp': 73.58,
#   'Humidity': 87,
#   'Cloudiness': 50,
#   'Wind Speed': 11.63,
#   'Country': 'ZA',
#   'Description': 'scattered clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 35.6,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Description': 'scattered clouds'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 74.84,
#   'Humidity': 89,
#   'Cloudiness': 59,
#   'Wind Speed': 10.47,
#   'Country': 'CN',
#   'Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 78.53,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 36.82,
#   'Country': 'NC',
#   'Description': 'heavy intensity rain'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 66.2,
#   'Humidity': 55,
#   'Cloudiness': 98,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Shieli',
#   'Lat': 44.1667,
#   'Lng': 66.75,
#   'Max Temp': 50.59,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 15.32,
#   'Country': 'KZ',
#   'Description': 'clear sky'},
#  {'City': 'Kibala',
#   'Lat': 9.1104,
#   'Lng': 18.3463,
#   'Max Temp': 95,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 4.03,
#   'Country': 'TD',
#   'Description': 'clear sky'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 80.01,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Description': 'light rain'},
#  {'City': 'Iquique',
#   'Lat': -20.2208,
# ...
#   'Lng': 136.6092,
#   'Max Temp': 38.32,
#   'Humidity': 64,
#   'Cloudiness': 12,
#   'Wind Speed': 4.83,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Calvia',
#   'Lat': 39.5657,
#   'Lng': 2.5062,
#   'Max Temp': 60.01,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Country': 'ES',
#   'Description': 'few clouds'},
#  {'City': 'Rize',
#   'Lat': 40.9044,
#   'Lng': 40.8949,
#   'Max Temp': 29.61,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'TR',
#   'Description': 'light snow'},
#  {'City': 'Wana',
#   'Lat': 32.2989,
#   'Lng': 69.5725,
#   'Max Temp': 66.16,
#   'Humidity': 34,
#   'Cloudiness': 41,
#   'Wind Speed': 4.25,
#   'Country': 'PK',
#   'Description': 'scattered clouds'},
#  {'City': 'Bundaberg',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 70,
#   'Humidity': 88,
#   'Cloudiness': 11,
#   'Wind Speed': 5.88,
#   'Country': 'AU',
#   'Description': 'few clouds'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 68,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 10.45,
#   'Country': 'SA',
#   'Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 81,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'San Nicolas',
#   'Lat': 18.1725,
#   'Lng': 120.5953,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Country': 'PH',
#   'Description': 'few clouds'},
#  {'City': 'Consett',
#   'Lat': 54.854,
#   'Lng': -1.8316,
#   'Max Temp': 39.99,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'GB',
#   'Description': 'overcast clouds'},
#  {'City': 'Dolores',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 63.19,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 17.72,
#   'Country': 'AR',
#   'Description': 'overcast clouds'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 25.79,
#   'Humidity': 88,
#   'Cloudiness': 11,
#   'Wind Speed': 11.3,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Launceston',
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp': 39,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Description': 'scattered clouds'},
#  {'City': 'Brownwood',
#   'Lat': 31.7093,
#   'Lng': -98.9912,
#   'Max Temp': 68,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 14.32,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Tomohon',
#   'Lat': 1.3346,
#   'Lng': 124.8392,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'ID',
#   'Description': 'scattered clouds'},
#  {'City': 'Tymovskoye',
#   'Lat': 50.8456,
#   'Lng': 142.655,
#   'Max Temp': 26.47,
#   'Humidity': 89,
#   'Cloudiness': 38,
#   'Wind Speed': 7.25,
#   'Country': 'RU',
#   'Description': 'scattered clouds'},
#  {'City': 'Mutare',
#   'Lat': -18.9707,
#   'Lng': 32.6709,
#   'Max Temp': 61.02,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Country': 'ZW',
#   'Description': 'clear sky'},
#  {'City': 'Rizhao',
#   'Lat': 35.4275,
#   'Lng': 119.4553,
#   'Max Temp': 48.76,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.5,
#   'Country': 'CN',
#   'Description': 'light rain'},
#  {'City': 'Kharp',
#   'Lat': 66.8014,
#   'Lng': 65.8081,
#   'Max Temp': 29.8,
#   'Humidity': 96,
#   'Cloudiness': 91,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Bridgetown',
#   'Lat': 13.1,
#   'Lng': -59.6167,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'BB',
#   'Description': 'volcanic ash'},
#  {'City': 'Cantaura',
#   'Lat': 9.3057,
#   'Lng': -64.3584,
#   'Max Temp': 86.83,
#   'Humidity': 50,
#   'Cloudiness': 99,
#   'Wind Speed': 3.4,
#   'Country': 'VE',
#   'Description': 'overcast clouds'},
#  {'City': 'Chiang Kham',
#   'Lat': 19.5233,
#   'Lng': 100.3,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'TH',
#   'Description': 'clear sky'},
#  {'City': 'Lesnoye',
#   'Lat': 58.2841,
#   'Lng': 35.5158,
#   'Max Temp': 43.86,
#   'Humidity': 67,
#   'Cloudiness': 99,
#   'Wind Speed': 12.77,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Ca Mau',
#   'Lat': 9.1769,
#   'Lng': 105.15,
#   'Max Temp': 80.87,
#   'Humidity': 75,
#   'Cloudiness': 7,
#   'Wind Speed': 8.1,
#   'Country': 'VN',
#   'Description': 'clear sky'},
#  {'City': 'Matam',
#   'Lat': 15.6175,
#   'Lng': -13.3303,
#   'Max Temp': 111.2,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'SN',
#   'Description': 'clear sky'},
#  {'City': 'Yorkton',
#   'Lat': 51.2167,
#   'Lng': -102.4677,
#   'Max Temp': 57.2,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 28.47,
#   'Humidity': 70,
#   'Cloudiness': 88,
#   'Wind Speed': 14.12,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Isla Vista',
#   'Lat': 34.4133,
#   'Lng': -119.861,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 75.99,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'PH',
#   'Description': 'overcast clouds'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 6.75,
#   'Humidity': 77,
#   'Cloudiness': 62,
#   'Wind Speed': 10.89,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Newton',
#   'Lat': 42.337,
#   'Lng': -71.2092,
#   'Max Temp': 77,
#   'Humidity': 46,
#   'Cloudiness': 22,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Description': 'few clouds'},
#  {'City': 'Murray Bridge',
#   'Lat': -35.1167,
#   'Lng': 139.2667,
#   'Max Temp': 54,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 17.29,
#   'Country': 'AU',
#   'Description': 'overcast clouds'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 46,
#   'Humidity': 56,
#   'Cloudiness': 96,
#   'Wind Speed': 5.01,
#   'Country': 'JP',
#   'Description': 'overcast clouds'},
#  {'City': 'Roblin',
#   'Lat': 51.23,
#   'Lng': -101.3565,
#   'Max Temp': 50.83,
#   'Humidity': 30,
#   'Cloudiness': 62,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Description': 'broken clouds'},
#  {'City': 'Areia Branca',
#   'Lat': -4.9561,
#   'Lng': -37.1369,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Lahijan',
#   'Lat': 37.2061,
#   'Lng': 50.0029,
#   'Max Temp': 55.4,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'IR',
#   'Description': 'mist'},
#  {'City': 'Nadym',
#   'Lat': 65.5333,
#   'Lng': 72.5167,
#   'Max Temp': 26.73,
#   'Humidity': 92,
#   'Cloudiness': 33,
#   'Wind Speed': 10.13,
#   'Country': 'RU',
#   'Description': 'scattered clouds'},
#  {'City': 'Caucasia',
#   'Lat': 7.9865,
#   'Lng': -75.1935,
#   'Max Temp': 89.15,
#   'Humidity': 56,
#   'Cloudiness': 90,
#   'Wind Speed': 5.95,
#   'Country': 'CO',
#   'Description': 'overcast clouds'},
#  {'City': 'Letpadan',
#   'Lat': 17.7833,
#   'Lng': 95.75,
#   'Max Temp': 83.07,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 7.78,
#   'Country': 'MM',
#   'Description': 'clear sky'},
#  {'City': 'Martapura',
#   'Lat': -3.4167,
#   'Lng': 114.85,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'ID',
#   'Description': 'overcast clouds'},
#  {'City': 'Emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 69.8,
#   'Humidity': 52,
#   'Cloudiness': 58,
#   'Wind Speed': 3.44,
#   'Country': 'AU',
#   'Description': 'light rain'},
#  {'City': 'Glossa',
#   'Lat': 35.4717,
#   'Lng': 23.7763,
#   'Max Temp': 53.6,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 6.17,
#   'Country': 'GR',
#   'Description': 'few clouds'},
#  {'City': 'Batagay',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': -26.79,
#   'Humidity': 100,
#   'Cloudiness': 73,
#   'Wind Speed': 2.42,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Agadez',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 88.86,
#   'Humidity': 4,
#   'Cloudiness': 0,
#   'Wind Speed': 8.68,
#   'Country': 'NE',
#   'Description': 'clear sky'},
#  {'City': 'Anahuac',
#   'Lat': 27.2333,
#   'Lng': -100.15,
#   'Max Temp': 80.6,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Country': 'MX',
#   'Description': 'clear sky'},
#  {'City': 'Maun',
#   'Lat': -19.9833,
#   'Lng': 23.4167,
#   'Max Temp': 75.2,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'BW',
#   'Description': 'clear sky'},
#  {'City': 'Cesenatico',
#   'Lat': 44.1999,
#   'Lng': 12.3991,
#   'Max Temp': 57,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'IT',
#   'Description': 'overcast clouds'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 77.41,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Country': 'MG',
#   'Description': 'light rain'},
#  {'City': 'Havoysund',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 32,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'NO',
#   'Description': 'few clouds'},
#  {'City': 'Cap-Aux-Meules',
#   'Lat': 47.3821,
#   'Lng': -61.8597,
#   'Max Temp': 33.8,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 19.57,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Phan Thiet',
#   'Lat': 10.9333,
#   'Lng': 108.1,
#   'Max Temp': 76.86,
#   'Humidity': 83,
#   'Cloudiness': 71,
#   'Wind Speed': 9.78,
#   'Country': 'VN',
#   'Description': 'broken clouds'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 83.03,
#   'Humidity': 74,
#   'Cloudiness': 70,
#   'Wind Speed': 13.71,
#   'Country': 'SO',
#   'Description': 'broken clouds'},
#  {'City': 'Shaunavon',
#   'Lat': 49.6501,
#   'Lng': -108.4181,
#   'Max Temp': 46.4,
#   'Humidity': 31,
#   'Cloudiness': 66,
#   'Wind Speed': 23.02,
#   'Country': 'CA',
#   'Description': 'broken clouds'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 27.55,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 5.93,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Suining',
#   'Lat': 30.508,
#   'Lng': 105.5733,
#   'Max Temp': 56.75,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'CN',
#   'Description': 'overcast clouds'},
#  {'City': 'Nago',
#   'Lat': 26.5881,
#   'Lng': 127.9761,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 18.41,
#   'Country': 'JP',
#   'Description': 'clear sky'},
#  {'City': 'Zhanakorgan',
#   'Lat': 43.9098,
#   'Lng': 67.2495,
#   'Max Temp': 50.77,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 18.61,
#   'Country': 'KZ',
#   'Description': 'clear sky'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 11.12,
#   'Country': 'PW',
#   'Description': 'broken clouds'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'BR',
#   'Description': 'moderate rain'},
#  {'City': 'Calera',
#   'Lat': 33.1029,
#   'Lng': -86.7536,
#   'Max Temp': 73,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Description': 'scattered clouds'},
#  {'City': 'Lakes Entrance',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 46,
#   'Humidity': 84,
#   'Cloudiness': 81,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Description': 'broken clouds'},
#  {'City': 'Dolinsk',
#   'Lat': 47.35,
#   'Lng': 142.8,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Tutoia',
#   'Lat': -2.7619,
#   'Lng': -42.2744,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Description': 'few clouds'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 69,
#   'Wind Speed': 2.3,
#   'Country': 'AU',
#   'Description': 'broken clouds'},
#  {'City': 'Babaeski',
#   'Lat': 41.4325,
#   'Lng': 27.0931,
#   'Max Temp': 39.13,
#   'Humidity': 68,
#   'Cloudiness': 32,
#   'Wind Speed': 7.78,
#   'Country': 'TR',
#   'Description': 'scattered clouds'},
#  {'City': 'Mwinilunga',
#   'Lat': -11.7358,
#   'Lng': 24.4293,
#   'Max Temp': 62.06,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 4.27,
#   'Country': 'ZM',
#   'Description': 'overcast clouds'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 85.14,
#   'Humidity': 68,
#   'Cloudiness': 64,
#   'Wind Speed': 16.91,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Nogliki',
#   'Lat': 51.8333,
#   'Lng': 143.1667,
#   'Max Temp': 22.86,
#   'Humidity': 91,
#   'Cloudiness': 53,
#   'Wind Speed': 7.96,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Johi',
#   'Lat': 26.6921,
#   'Lng': 67.6133,
#   'Max Temp': 89.29,
#   'Humidity': 8,
#   'Cloudiness': 5,
#   'Wind Speed': 4.34,
#   'Country': 'PK',
#   'Description': 'clear sky'},
#  {'City': 'Vermilion',
#   'Lat': 40.1667,
#   'Lng': -87.7506,
#   'Max Temp': 61,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Kota Belud',
#   'Lat': 6.351,
#   'Lng': 116.4305,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'MY',
#   'Description': 'few clouds'},
#  {'City': 'Invermere',
#   'Lat': 50.5167,
#   'Lng': -116.0354,
#   'Max Temp': 41.54,
#   'Humidity': 32,
#   'Cloudiness': 99,
#   'Wind Speed': 3.69,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Rorvik',
#   'Lat': 64.8621,
#   'Lng': 11.2373,
#   'Max Temp': 39.25,
#   'Humidity': 67,
#   'Cloudiness': 97,
#   'Wind Speed': 13.69,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Umiray',
#   'Lat': 15.2206,
#   'Lng': 121.4111,
#   'Max Temp': 78.04,
#   'Humidity': 83,
#   'Cloudiness': 72,
#   'Wind Speed': 14.47,
#   'Country': 'PH',
#   'Description': 'broken clouds'},
#  {'City': 'Van',
#   'Lat': 38.4924,
#   'Lng': 43.3831,
#   'Max Temp': 55.4,
#   'Humidity': 44,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'TR',
#   'Description': 'light rain'},
#  {'City': 'Ust-Kut',
#   'Lat': 56.7938,
#   'Lng': 105.7672,
#   'Max Temp': 7.9,
#   'Humidity': 97,
#   'Cloudiness': 94,
#   'Wind Speed': 1.88,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Bagdarin',
#   'Lat': 54.4333,
#   'Lng': 113.6,
#   'Max Temp': 11.07,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 3.76,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Vung Tau',
#   'Lat': 10.346,
#   'Lng': 107.0843,
#   'Max Temp': 81.14,
#   'Humidity': 80,
#   'Cloudiness': 73,
#   'Wind Speed': 22.75,
#   'Country': 'VN',
#   'Description': 'broken clouds'},
#  {'City': 'Camara De Lobos',
#   'Lat': 32.6333,
#   'Lng': -16.9667,
#   'Max Temp': 68,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'PT',
#   'Description': 'broken clouds'},
#  {'City': 'Ndjole',
#   'Lat': -0.1783,
#   'Lng': 10.7649,
#   'Max Temp': 77.41,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 1.86,
#   'Country': 'GA',
#   'Description': 'overcast clouds'},
#  {'City': 'Eydhafushi',
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 83.57,
#   'Humidity': 66,
#   'Cloudiness': 21,
#   'Wind Speed': 5.59,
#   'Country': 'MV',
#   'Description': 'few clouds'},
#  {'City': 'Tuy Hoa',
#   'Lat': 13.0833,
#   'Lng': 109.3,
#   'Max Temp': 75.79,
#   'Humidity': 90,
#   'Cloudiness': 59,
#   'Wind Speed': 3.53,
#   'Country': 'VN',
#   'Description': 'broken clouds'},
#  {'City': 'Palembang',
#   'Lat': -2.9167,
#   'Lng': 104.7458,
#   'Max Temp': 75.31,
#   'Humidity': 92,
#   'Cloudiness': 63,
#   'Wind Speed': 2.93,
#   'Country': 'ID',
#   'Description': 'broken clouds'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 75.99,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'NA',
#   'Description': 'clear sky'},
#  {'City': 'Cajnice',
#   'Lat': 43.5575,
#   'Lng': 19.0711,
#   'Max Temp': 53.6,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'BA',
#   'Description': 'clear sky'}]

# %%
# Add the data to a new DataFrame by converting the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df.head(2)
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Mataura -46.1927  168.8643     57.00        93          96        5.01
# 1   Searcy  35.2506  -91.7363     66.99        52           1       13.80
#
#   Country      Description
# 0      NZ  overcast clouds
# 1      US        clear sky

# %%
#reorganize the column order
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Description","Max Temp","Humidity", "Cloudiness", "Wind Speed"]]

city_data_df.head(2)
# Out:
#       City Country      Lat       Lng      Description  Max Temp  Humidity  \
# 0  Mataura      NZ -46.1927  168.8643  overcast clouds     57.00        93
# 1   Searcy      US  35.2506  -91.7363        clear sky     66.99        52
#
#    Cloudiness  Wind Speed
# 0          96        5.01
# 1           1       13.80

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create an output csv in the right folder
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export city_data df into that file
city_data_df.to_csv(output_data_file, index_label="City_ID")
